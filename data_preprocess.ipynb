# %%
import pandas as pd  # 导入 pandas 模块，用于数据处理
import seaborn as sns  # 导入 seaborn 模块，用于绘制统计图表
import matplotlib.pyplot as plt  # 导入 matplotlib.pyplot 模块，用于绘图

# %%
df=pd.read_csv('douban_movie_reviews.csv')
df
# Out:
#                                              URL  \
# 0      https://movie.douban.com/subject/1292052/
# 1      https://movie.douban.com/subject/1292052/
# 2      https://movie.douban.com/subject/1292052/
# 3      https://movie.douban.com/subject/1292052/
# 4      https://movie.douban.com/subject/1292052/
# ...                                          ...
# 8594  https://movie.douban.com/subject/26615208/
# 8595  https://movie.douban.com/subject/26615208/
# 8596  https://movie.douban.com/subject/26615208/
# 8597  https://movie.douban.com/subject/26615208/
# 8598  https://movie.douban.com/subject/26615208/
#
#                                                  Review  Rating
# 0     当年的奥斯卡颁奖礼上，被如日中天的《阿甘正传》掩盖了它的光彩，而随着时间的推移，这部电影在越...     5.0
# 1                          恐惧让你沦为囚犯，希望让你重获自由。——《肖申克的救赎》     5.0
# 2     “这是一部男人必看的电影。”人人都这么说。但单纯从性别区分，就会让这电影变狭隘。《肖申克的救...     5.0
# 3            人的生命不过是从一个洞穴通往另一个世界..然后在那个世界的雨中继续颤抖.i hope     4.0
# 4                                           策划了19年的私奔……     5.0
# ...                                                 ...     ...
# 8594  配乐、表演很不错，用喜剧的形式表现种族问题，很可贵。 全场爆笑，中间有几次鼓掌，最后全体起立...     5.0
# 8595  有太多“乏味的科学家电影”，能看到这部电影真好。读完同名著作让我久久不能平息，到最后略四平八...     4.0
# 8596                                   看完有种立刻投入工作当中去的冲动     5.0
# 8597  五星并不是代表是最好的，只因我们依然需要这样的电影。意外的明亮欢快。知道是主旋律刻意煽情，可...     5.0
# 8598      发射室里在一群满是穿着白衬衫的白人男性中，凯瑟琳的黑色皮肤和红色裙子，成为了最耀眼的光芒。     5.0
#
# [8599 rows x 3 columns]

# %%
# 过滤掉评分为'无评分'的行
df = df[df['Rating'] != '无评分']
# 删除包含缺失值的行，针对'Rating'列
df.dropna(subset=['Rating'], inplace=True)

# %%
df
# Out:
#                                              URL  \
# 0      https://movie.douban.com/subject/1292052/
# 1      https://movie.douban.com/subject/1292052/
# 2      https://movie.douban.com/subject/1292052/
# 3      https://movie.douban.com/subject/1292052/
# 4      https://movie.douban.com/subject/1292052/
# ...                                          ...
# 8594  https://movie.douban.com/subject/26615208/
# 8595  https://movie.douban.com/subject/26615208/
# 8596  https://movie.douban.com/subject/26615208/
# 8597  https://movie.douban.com/subject/26615208/
# 8598  https://movie.douban.com/subject/26615208/
#
#                                                  Review  Rating
# 0     当年的奥斯卡颁奖礼上，被如日中天的《阿甘正传》掩盖了它的光彩，而随着时间的推移，这部电影在越...     5.0
# 1                          恐惧让你沦为囚犯，希望让你重获自由。——《肖申克的救赎》     5.0
# 2     “这是一部男人必看的电影。”人人都这么说。但单纯从性别区分，就会让这电影变狭隘。《肖申克的救...     5.0
# 3            人的生命不过是从一个洞穴通往另一个世界..然后在那个世界的雨中继续颤抖.i hope     4.0
# 4                                           策划了19年的私奔……     5.0
# ...                                                 ...     ...
# 8594  配乐、表演很不错，用喜剧的形式表现种族问题，很可贵。 全场爆笑，中间有几次鼓掌，最后全体起立...     5.0
# 8595  有太多“乏味的科学家电影”，能看到这部电影真好。读完同名著作让我久久不能平息，到最后略四平八...     4.0
# 8596                                   看完有种立刻投入工作当中去的冲动     5.0
# 8597  五星并不是代表是最好的，只因我们依然需要这样的电影。意外的明亮欢快。知道是主旋律刻意煽情，可...     5.0
# 8598      发射室里在一群满是穿着白衬衫的白人男性中，凯瑟琳的黑色皮肤和红色裙子，成为了最耀眼的光芒。     5.0
#
# [8513 rows x 3 columns]

# %%
df['Review_length'] = df['Review'].apply(len)

# %%
df
# Out:
#                                              URL  \
# 0      https://movie.douban.com/subject/1292052/
# 1      https://movie.douban.com/subject/1292052/
# 2      https://movie.douban.com/subject/1292052/
# 3      https://movie.douban.com/subject/1292052/
# 4      https://movie.douban.com/subject/1292052/
# ...                                          ...
# 8594  https://movie.douban.com/subject/26615208/
# 8595  https://movie.douban.com/subject/26615208/
# 8596  https://movie.douban.com/subject/26615208/
# 8597  https://movie.douban.com/subject/26615208/
# 8598  https://movie.douban.com/subject/26615208/
#
#                                                  Review  Rating  Review_length
# 0     当年的奥斯卡颁奖礼上，被如日中天的《阿甘正传》掩盖了它的光彩，而随着时间的推移，这部电影在越...     5.0            160
# 1                          恐惧让你沦为囚犯，希望让你重获自由。——《肖申克的救赎》     5.0             28
# 2     “这是一部男人必看的电影。”人人都这么说。但单纯从性别区分，就会让这电影变狭隘。《肖申克的救...     5.0            218
# 3            人的生命不过是从一个洞穴通往另一个世界..然后在那个世界的雨中继续颤抖.i hope     4.0             42
# 4                                           策划了19年的私奔……     5.0             11
# ...                                                 ...     ...            ...
# 8594  配乐、表演很不错，用喜剧的形式表现种族问题，很可贵。 全场爆笑，中间有几次鼓掌，最后全体起立...     5.0             71
# 8595  有太多“乏味的科学家电影”，能看到这部电影真好。读完同名著作让我久久不能平息，到最后略四平八...     4.0            141
# 8596                                   看完有种立刻投入工作当中去的冲动     5.0             16
# 8597  五星并不是代表是最好的，只因我们依然需要这样的电影。意外的明亮欢快。知道是主旋律刻意煽情，可...     5.0            140
# 8598      发射室里在一群满是穿着白衬衫的白人男性中，凯瑟琳的黑色皮肤和红色裙子，成为了最耀眼的光芒。     5.0             45
#
# [8513 rows x 4 columns]

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 5.0    2663
# 3.0    1975
# 2.0    1632
# 4.0    1598
# 1.0     645
# Name: count, dtype: int64

# %%
# 计算评论长度的 95% 分位数
length_quantile_95 = df['Review_length'].quantile(0.95)
print(length_quantile_95)
# Out:
# 204.0

# %%
###查看Review的字符长度分布
# 设置 seaborn 的样式为白色网格
sns.set(style="whitegrid")
# 创建一个新的图表，指定尺寸为(10, 6)
plt.figure(figsize=(10, 6))
# 绘制评论长度的直方图
sns.distplot(df['Review_length'], kde=False, bins=30, color='blue')  # kde=False 表示不显示核密度估计曲线，bins 控制柱状图的数量
# 设置图表标题、x轴标签和y轴标签
plt.title('Review Length Distribution')
plt.xlabel('Length')
plt.ylabel('Frequency')
# 显示图表
plt.show()
# Out:
# C:\Users\吴天添\AppData\Local\Temp\ipykernel_25648\2610568271.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Review_length'], kde=False, bins=30, color='blue')  # kde=False 表示不显示核密度估计曲线，bins 控制柱状图的数量

# %%
# 定义映射字典：原始分数 -> 新标签
rating_map = {1: 1, 2: 1, 3: 2, 4: 3, 5: 4}

# 使用 map() 方法转换 Rating 列
df['Rating'] = df['Rating'].map(rating_map)

# %%
df = df[['Review', 'Rating']]

# %%
df = df[df['Review'].str.len() > 5] #  remove short reviews

# %%
df
# Out:
#                                                  Review  Rating
# 0     当年的奥斯卡颁奖礼上，被如日中天的《阿甘正传》掩盖了它的光彩，而随着时间的推移，这部电影在越...       4
# 1                          恐惧让你沦为囚犯，希望让你重获自由。——《肖申克的救赎》       4
# 2     “这是一部男人必看的电影。”人人都这么说。但单纯从性别区分，就会让这电影变狭隘。《肖申克的救...       4
# 3            人的生命不过是从一个洞穴通往另一个世界..然后在那个世界的雨中继续颤抖.i hope       3
# 4                                           策划了19年的私奔……       4
# ...                                                 ...     ...
# 8594  配乐、表演很不错，用喜剧的形式表现种族问题，很可贵。 全场爆笑，中间有几次鼓掌，最后全体起立...       4
# 8595  有太多“乏味的科学家电影”，能看到这部电影真好。读完同名著作让我久久不能平息，到最后略四平八...       3
# 8596                                   看完有种立刻投入工作当中去的冲动       4
# 8597  五星并不是代表是最好的，只因我们依然需要这样的电影。意外的明亮欢快。知道是主旋律刻意煽情，可...       4
# 8598      发射室里在一群满是穿着白衬衫的白人男性中，凯瑟琳的黑色皮肤和红色裙子，成为了最耀眼的光芒。       4
#
# [8355 rows x 2 columns]

# %%
df.drop_duplicates(inplace=True) # 删掉重复值
# Out:
# C:\Users\吴天添\AppData\Local\Temp\ipykernel_25648\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                                  Review  Rating
# 0     当年的奥斯卡颁奖礼上，被如日中天的《阿甘正传》掩盖了它的光彩，而随着时间的推移，这部电影在越...       4
# 1                          恐惧让你沦为囚犯，希望让你重获自由。——《肖申克的救赎》       4
# 2     “这是一部男人必看的电影。”人人都这么说。但单纯从性别区分，就会让这电影变狭隘。《肖申克的救...       4
# 3            人的生命不过是从一个洞穴通往另一个世界..然后在那个世界的雨中继续颤抖.i hope       3
# 4                                           策划了19年的私奔……       4
# ...                                                 ...     ...
# 8554  配乐、表演很不错，用喜剧的形式表现种族问题，很可贵。 全场爆笑，中间有几次鼓掌，最后全体起立...       4
# 8555  有太多“乏味的科学家电影”，能看到这部电影真好。读完同名著作让我久久不能平息，到最后略四平八...       3
# 8556                                   看完有种立刻投入工作当中去的冲动       4
# 8557  五星并不是代表是最好的，只因我们依然需要这样的电影。意外的明亮欢快。知道是主旋律刻意煽情，可...       4
# 8558      发射室里在一群满是穿着白衬衫的白人男性中，凯瑟琳的黑色皮肤和红色裙子，成为了最耀眼的光芒。       4
#
# [7132 rows x 2 columns]

# %%
# 保存到新的 CSV 文件
df.to_csv('clean_data.csv', index=False, encoding='utf-8')
